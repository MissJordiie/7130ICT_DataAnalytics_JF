# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv('job-market.csv')
data.head()
df = pd.DataFrame(data)
df
# Out:
#                Id                                              Title  \
# 0      37404348.0                           Casual Stock Replenisher
# 1      37404337.0                           Casual Stock Replenisher
# 2      37404356.0  RETAIL SALES SUPERSTARS and STYLISTS Wanted - ...
# 3      37404330.0                              Team member - Belrose
# 4      37404308.0  Business Banking Contact Centre Specialist, Ni...
# ...           ...                                                ...
# 40784         NaN                                                NaN
# 40785         NaN                                                NaN
# 40786         NaN                                                NaN
# 40787         NaN                                                NaN
# 40788         NaN                                                NaN
#
#                                               Company  \
# 0                                         Aldi Stores
# ...

# %%
# %matplotlib inline

# %%
df['Count'] = df.groupby('Location')['Location'].transform('count')
nj = df.loc[:,("Location", "Count")]
nj
# Out:
#                       Location   Count
# 0                       Sydney  2784.0
# 1        Richmond & Hawkesbury    10.0
# 2                     Brisbane  1119.0
# 3      Gosford & Central Coast    80.0
# 4                       Sydney  2784.0
# ...                        ...     ...
# 40784                      NaN     NaN
# 40785                      NaN     NaN
# 40786                      NaN     NaN
# 40787                      NaN     NaN
# 40788                      NaN     NaN
#
# [40789 rows x 2 columns]

# %%
jp = df.groupby('Location')['Area'].value_counts()
jp
# Out:
# Location   Area
# Brisbane   CBD & Inner Suburbs                     575
#            Southern Suburbs & Logan                142
#            Northern Suburbs                        141
#            Western Suburbs & Ipswich                82
#            Bayside & Eastern Suburbs                47
# Melbourne  CBD & Inner Suburbs                     881
#            Bayside & South Eastern Suburbs         485
#            Eastern Suburbs                         351
#            Western Suburbs                         292
#            Northern Suburbs                        281
# Perth      CBD, Inner & Western Suburbs            250
#            Fremantle & Southern Suburbs            109
#            Northern Suburbs & Joondalup            105
#            Eastern Suburbs                          78
#            Rockingham & Kwinana                     21
# Sydney     CBD, Inner West & Eastern Suburbs      1141
#            Parramatta & Western Suburbs            462
# ...

# %%
DataF = pd.DataFrame(nj)
DataF
# Out:
#                       Location   Count
# 0                       Sydney  2784.0
# 1        Richmond & Hawkesbury    10.0
# 2                     Brisbane  1119.0
# 3      Gosford & Central Coast    80.0
# 4                       Sydney  2784.0
# ...                        ...     ...
# 40784                      NaN     NaN
# 40785                      NaN     NaN
# 40786                      NaN     NaN
# 40787                      NaN     NaN
# 40788                      NaN     NaN
#
# [40789 rows x 2 columns]

# %%
DataF = DataF.drop_duplicates(subset=['Location', 'Count'], keep='last')

# %%
DataF = DataF.dropna(subset=['Location', 'Count'])
DataF
# Out:
#                              Location   Count
# 5341               Somerset & Lockyer     4.0
# 6210         Coober Pedy & Outback SA     1.0
# 6488   Katherine & Northern Australia     6.0
# 7814              Northam & Wheatbelt     6.0
# 8048                 Mildura & Murray    15.0
# ...                               ...     ...
# 10092                             ACT   238.0
# 10093                           Perth   677.0
# 10095                       Melbourne  2481.0
# 10097                        Brisbane  1119.0
# 10098                          Sydney  2784.0
#
# [65 rows x 2 columns]

# %%
X = list(DataF.iloc[:, 0])
Y = list(DataF.iloc[:, 1])

# %%
plt.bar(X, Y, color='g')
plt.title("Number of Job Postings by Location")
plt.xlabel("Location")
plt.ylabel("Number of Job Postings")
plt.xticks(fontsize = 5)
plt.xticks(rotation=45, ha='right')
plt.show()

# %%
df = df.dropna()
df
# Out:
#                Id                                         Title  \
# 121    37404238.0                          Fabricator/Installer
# 122    37404195.0                                   Boilermaker
# 125    37404288.0  Casual Childcare Positions  | Bondi Junction
# 126    37404267.0                                    Technician
# 127    37404230.0                              Systems Engineer
# ...           ...                                           ...
# 10091  37388929.0                            Lead Kit Assembler
# 10094  37388912.0                           Executive Assistant
# 10096  37388901.0                  Receptionist / Administrator
# 10097  37388898.0     INTERNATIONAL WHOLESALE TRAVEL CONSULTANT
# 10098  37388893.0               Customer Service Representative
#
#                            Company                      Date   Location  \
# 121      WORKPLACE ACCESS & SAFETY  2018-10-07T00:00:00.000Z  Melbourne
# ...

# %%
salr = df.loc[:,("LowestSalary", "HighestSalary")]
salr
# Out:
#        LowestSalary  HighestSalary
# 121             0.0           30.0
# 122             0.0           30.0
# 125             0.0           30.0
# 126             0.0           30.0
# 127             0.0           30.0
# ...             ...            ...
# 10091          50.0           60.0
# 10094          50.0           60.0
# 10096          50.0           60.0
# 10097          50.0           60.0
# 10098          50.0           60.0
#
# [5898 rows x 2 columns]

# %%
sr = pd.DataFrame(salr)
sr
# Out:
#        LowestSalary  HighestSalary
# 121             0.0           30.0
# 122             0.0           30.0
# 125             0.0           30.0
# 126             0.0           30.0
# 127             0.0           30.0
# ...             ...            ...
# 10091          50.0           60.0
# 10094          50.0           60.0
# 10096          50.0           60.0
# 10097          50.0           60.0
# 10098          50.0           60.0
#
# [5898 rows x 2 columns]

# %%
ax = sns.scatterplot(x = "LowestSalary", y = "HighestSalary", data = sr)
