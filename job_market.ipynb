# %%
import pandas as pd
import numpy as numpy

# %%
# Load the data using Pandas
df = pd.read_csv("job-market.csv")

#TODO: Visualize the top 10 first Rows
df.head(10)
# Out:
#            Id                                              Title  \
# 0  37404348.0                           Casual Stock Replenisher
# 1  37404337.0                           Casual Stock Replenisher
# 2  37404356.0  RETAIL SALES SUPERSTARS and STYLISTS Wanted - ...
# 3  37404330.0                              Team member - Belrose
# 4  37404308.0  Business Banking Contact Centre Specialist, Ni...
# 5  37404307.0  Business Banking Contact Centre Specialist, Ni...
# 6  37404355.0               Casual Café All-rounder in Semaphore
# 7  37404350.0           Casual Café All-rounder in Woolloongabba
# 8  37404301.0                                       Telemarketer
# 9  37404286.0                       Casual Dish Hand in Brighton
#
#                                           Company                      Date  \
# 0                                     Aldi Stores  2018-10-07T00:00:00.000Z
# 1                                     Aldi Stores  2018-10-07T00:00:00.000Z
# ...

# %%
df.dtypes
# Out:
# Id                   float64
# Title                 object
# Company               object
# Date                  object
# Location              object
# Area                  object
# Classification        object
# SubClassification     object
# Requirement           object
# FullDescription       object
# LowestSalary         float64
# HighestSalary        float64
# JobType               object
# dtype: object

# %%
#TODO: fix the data type of column Date
from datetime import datetime
df['Date'] = df['Date'].astype(datetime)

df.dtypes
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_56132/1396818678.py in <module>
#       1 #TODO: fix the data type of column Date
#       2 from datetime import datetime
# ----> 3 df['Date'] = df['Date'].astype(datetime)
#       4
#       5 df.dtypes
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in astype(self, dtype, copy, errors)
#    5813         else:
#    5814             # else, only a single dtype is given
# -> 5815             new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    5816             return self._constructor(new_data).__finalize__(self, method="astype")
#    5817
#
# ~\anaconda3\lib\site-packages\pandas\core\internals\managers.py in astype(self, dtype, copy, errors)
#     416
#     417     def astype(self: T, dtype, copy: bool = False, errors: str = "raise") -> T:
# ...

# %%
# Calculate the average salary as a new column
df = df.assign(AverageSalary = df.loc[:, ['HighestSalary' , 'LowestSalary']].mean(axis=1))

df.head(10)
# Out:
#            Id                                              Title  \
# 0  37404348.0                           Casual Stock Replenisher
# 1  37404337.0                           Casual Stock Replenisher
# 2  37404356.0  RETAIL SALES SUPERSTARS and STYLISTS Wanted - ...
# 3  37404330.0                              Team member - Belrose
# 4  37404308.0  Business Banking Contact Centre Specialist, Ni...
# 5  37404307.0  Business Banking Contact Centre Specialist, Ni...
# 6  37404355.0               Casual Café All-rounder in Semaphore
# 7  37404350.0           Casual Café All-rounder in Woolloongabba
# 8  37404301.0                                       Telemarketer
# 9  37404286.0                       Casual Dish Hand in Brighton
#
#                                           Company                      Date  \
# 0                                     Aldi Stores  2018-10-07T00:00:00.000Z
# 1                                     Aldi Stores  2018-10-07T00:00:00.000Z
# ...
